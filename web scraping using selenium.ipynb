# %% [markdown]
# # Name: Hamzah Ahmad
# # Roll No.: i210254
# # Assignment 6

# %% [markdown]
# # Instruction

# %% [markdown]
# 1. Don’t plagiarize, Plagiarism would lead to straight zero
# 2. Clearly mention your NAME and ROLL NO#.
# 3. Late submissions are not allowed. Start Early.

# %%
# !pip install selenium

# %%
#import libraries
import time
import pandas as pd
from selenium import webdriver
from selenium.webdriver.edge.options import Options
from selenium.webdriver.common.keys import Keys
# from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By
from selenium.common.exceptions import NoSuchElementException

# %% [markdown]
# # Question 1  (10 marks)

# %% [markdown]
# Scrape 3 pages of reviews for a single product listing using product URL.<br /> Note: Product must have more than 1 review page. The code must be generic and should work for every product listing URL, with proper checks in place.

# %%
def fastScroll(driver):
    y = 500
    for timer in range(0,15):
         driver.execute_script("window.scrollTo(0, "+str(y)+")")
         y += 1000
         time.sleep(.05)
    driver.execute_script("window.scrollTo("+str(y)+",0)")

def scroll(driver):

    y = 500
    for timer in range(0,15):
         driver.execute_script("window.scrollTo(0, "+str(y)+")")
         y += 500
         time.sleep(.5)

import re
def Q3Scroll(driver):
    y = 500
    for timer in range(0,10):
         driver.execute_script("window.scrollTo(0, "+str(y)+")")
         y += 250
         time.sleep(.2)
    driver.execute_script("window.scrollTo("+str(y)+",0)")

def Q1bRemoveGarbage(text):
    punc = '''!()-[]{};:'"\,<>./?@#$%^&*_~'''
    text.lower()
    text=text.replace("/n","")
    for i in text:
        if i in punc:
            text=text.replace(i,"")
    emoji_pattern = re.compile("["
            u"\U0001F600-\U0001F64F"  # emoticons
            u"\U0001F300-\U0001F5FF"  # symbols & pictographs
            u"\U0001F680-\U0001F6FF"  # transport & map symbols
            u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                               "]+", flags=re.UNICODE)
    return text

# %%
url = 'https://www.daraz.pk/products/changhong-ruba-dc-inverter-chr-dd378sp-refrigerator-silver-i100924200-s1246294955.html?spm=a2o2r4.tm800107969.2453349570.2.60ab2fa9Vn0TIa&clickTrackInfo=%7B%22rs%22%3A%223.1934%22%2C%22ms%22%3A%223.1934%22%2C%22ifHitHot%22%3A%221%22%2C%22mt%22%3A%22HOT%22%2C%22is%22%3A%22267%22%2C%22tr_id%22%3A%220%22%2C%22type%22%3A%22itemFall%22%2C%22userid%22%3A%220%22%2C%22platform%22%3A%22android%22%2C%22venture%22%3A%22pk%22%2C%22itemid%22%3A%22100924200%22%2C%22gmv%22%3A%225676509.0%22%2C%22ctr_score%22%3A%221.0E-6%22%2C%22ccr_score%22%3A%221.0E-6%22%2C%22pvid%22%3A%2284490a44-4224-4ce8-9eef-ee0ef5d236a3%22%2C%22pos%22%3A%220%22%2C%22cvr_score%22%3A%221.0E-6%22%2C%22domain%22%3A%22bumblebee%22%2C%22pg%22%3A%2280197960%22%2C%22ids%22%3A%2295%22%2C%22scm%22%3A%221007.31558.286466%22%2C%22config%22%3A%2224417121%22%7D'
path='/Downloads/chromedriver_win32'
reviews= []
options = Options()
driver=webdriver.Chrome('chromedriver')
driver.get(url)
time.sleep(2)
names=[]
scroll(driver)
reviews=[]
# Out:
#  After order goods received 6days As it is received as per describe above Slightly hole in upper freezer belt can you please change belt pic already shared

# %%
# Out:
# This dog 😂
# This dog

# %%
for i in range(3):
    for x in range(1,6):
        name=driver.find_element(By.XPATH,'//div[@class="mod-reviews"]/div[{0}]/div[2]/span[1]'.format(x)).text
        names.append(name[3:])
        review=driver.find_element(By.XPATH,'//div[@class="mod-reviews"]/div[{0}]/div[3]/div[1]'.format(x)).text
        review=" "+review
        review=Q1b(review)
        reviews.append(review)

    nextbutton=driver.find_element(By.XPATH,'//div[@class="pdp-mod-review"]/div[3]/div[@class="next-pagination next-pagination-normal next-pagination-arrow-only next-pagination-medium medium review-pagination"]/div/button[2]')
    driver.execute_script('arguments[0].click()', nextbutton)
    time.sleep(2)

driver.quit()

# %%
dic={"Names":names,"Reviews":reviews}
df=pd.DataFrame.from_dict(dic)
df
# Out:
#             Names                                            Reviews
# 0          Hassan   a good value for money addition in our house ...
# 1       Toheed F.   pro's Excellent quality material \nexcellent ...
# 2           3***7   this seller is very responsible person reply ...
# 3           A***.   After order goods received 6days. As it is re...
# 4     Muhammad I.   Very good product \nWorking on solar system\n...
# 5           M. A.   Good product in optimal price.  \ncooperative...
# 6       Atazaz H.   zabardast 👌👌\ndelivered in 7days\npurchased t...
# 7       Sajjad R.   aik din pehly deliver hogya, build quality b ...
# 8     Muhammad I.   Delivered on time in excellent packing and sa...
# 9           3***1   Just arrived,yet to be set in a place n turn ...
# 10  ubaidullah K.   Good device and initial cooling is good. Didn...
# 11    Muhammad A.   Very quick service provided by saller. Best q...
# 12      Rizwan J.   mashallah freezer dekhne mein bahut khubsurat...
# ...

# %%
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
#Output
df
# Out:
#            Name                                        Review text
# 0     Nabeel B.  Cellphone is great, was delivered on said time...
# 1     Salman R.  Great response excellent delivery time and pro...
# 2   Mohammad H.  One of the best in it's category. highly recom...
# 3         M***.        Very good product daraz good service thankx
# 4      hamxa M.                  Original product and good packing
# 5    Saqlain A.  Sir warranty card pr koi date ya sign nai to b...
# 6          M D.  Mobile is original but seller is too lazy in t...
# 7         N***.      Phone is perfect but now prices are increased
# 8      umair K.                   best phone in this price range.
# 9      Imran K.                                 original product 👍

# %% [markdown]
# ### Question 1 Part b  (10 marks)

# %% [markdown]
# Clean the Reviews using NLTK,RE. Remove Punctuations, Smilies and other garbage using any library.
#
# Apply Vader Sentiment to find the sentiment of the review, and append it in a column named "Sentiment".
#
# You can get help of Vader sentiment from this; https://towardsdatascience.com/sentimental-analysis-using-vader-a3415fef7664

# %%
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
import numpy as np
import pandas as pd
sid = SentimentIntensityAnalyzer()
vanderlist=[]
df['sentiment']=df['text'].apply(lambda text: sid.polarity_scores(text) )
df

# %% [markdown]
# # Question 2   (20 marks)

# %% [markdown]
# Scrape 80 items for a keyword search e.g., 'mobile covers'<br/>Note: Must use "click()" function of webElement, URL changing for pages is not allowed. The code must be generic and should work for every keyword, with proper checks in place. Bonus for also scraping country and Daraz Mall availability.

# %%
def urlNorm(str1):
    punc = '''!()-[]{};:'"\,<>./?@#$%^&*_~'''
    str1.lower()
    for i in str1:
        if i in punc:
            str1=str1.replace(i,"")
    str1=str1.replace(" ","-")
    return str1
def checkcountry(driver):
        x=driver.find_element(By.XPATH,"//div[@class='delivery-option-item__title'][1]").text
        if (x=='Standard Delivery'):
            country='Pakistan'
        else:
            country='Overseas'
        return country
def checkStore(driver):
    try:
        x=driver.find_element(By.XPATH,'//div[@class="seller-name__detail"]/a/img')
        store='Daraz Mall'
    except:
        store='Private'
    return store

# %%
query = 'mobile covers'
query=urlNorm(query)
url = 'https://www.daraz.pk/{}/?page=1'.format(query)
url = 'https://www.daraz.pk/mobile-cases-covers/?page=1'
path='/Downloads/chromedriver_win32'
options = Options()
driver=webdriver.Chrome('chromedriver')
driver.get(url)
Name=[]
Store=[]
Country=[]
Stars=[]
Reviews=[]
Price=[]
count=0
for j in range(0,2):
    for i in range(1,41):
        fastScroll(driver)
        time.sleep(1)

        button=driver.find_element(By.XPATH,'//div[@class="box--ujueT"]/div[@class="gridItem--Yd0sa"][{}]'.format(i))
        button.click()
        try:
            driver.find_element(By.XPATH,"//span[@class='sfo__close']").click()

        except:
            x=1
        scroll(driver)
        time.sleep(.2)
        name =driver.find_element(By.XPATH,"//span[@class='pdp-mod-product-badge-title']").text
        Name.append(name)
        price=driver.find_element(By.XPATH,"//div[@class='pdp-product-price']/span").text
        stars=driver.find_element(By.XPATH,"//span[@class='score-average']").text
        reviews=driver.find_element(By.XPATH,"//div[@class='count']").text
        price=price[4:]
        reviews=reviews[:-7]
        count=count+1
        print(stars)
        print(count)
        Price.append(price)
        Stars.append(stars)
        Reviews.append(reviews)
        Store.append(checkStore(driver))
        Country.append(checkcountry(driver))
        time.sleep(1)
        driver.back()
    nextPage= driver.find_element(By.XPATH,"//li[@title='Next Page']")
    nextPage.click()
driver.quit()
# Out:
# 5.0
# 1
# 4.8
# 2
# 4.9
# 3
# 4.8
# 4
# 4.4
# 5
# 4.8
# 6
# 4.9
# 7
# 4.8
# 8
# 5.0
# 9
# 5.0
# 10
# 4.8
# 11
# 5.0
# 12
# 4.8
# 13
# 4.7
# 14
# 4.8
# 15
# 4.9
# 16
# 5.0
# 17
# 4.7
# 18
# 4.5
# 19
# 4.6
# 20
# 4.9
# 21
# 4.8
# 22
# 4.9
# 23
# 4.8
# 24
# 4.5
# 25
# 5.0
# 26
# 4.5
# 27
# 4.8
# 28
# 4.9
# 29
# 4.8
# 30
# 5.0
# 31
# 4.4
# 32
# 5.0
# 33
# 4.7
# 34
# 5.0
# 35
# 5.0
# 36
# 4.5
# 37
# 4.7
# 38
# 5.0
# 39
# 4.5
# 40
# 4.9
# 41
# 5.0
# 42
# 5.0
# 43
# 4.8
# 44
# 4.9
# 45
# 4.8
# 46
# 4.4
# 47
# 4.8
# 48
# 4.9
# 49
# 4.8
# 50
# 5.0
# 51
# 5.0
# 52
# 4.8
# 53
# 5.0
# 54
# 4.8
# 55
# 4.7
# 56
# 4.8
# 57
# 4.9
# 58
# 5.0
# 59
# 4.7
# 60
# 4.5
# 61
# 4.6
# 62
# 4.9
# 63
# 4.8
# 64
# 4.9
# 65
# 4.8
# 66
# 4.5
# 67
# 5.0
# 68
# 4.5
# 69
# 4.8
# 70
# 4.9
# 71
# 5.0
# 72
# 4.4
# 73
# 5.0
# 74
# 4.7
# 75
# 5.0
# 76
# 5.0
# 77
# 4.5
# 78
# 4.7
# 79
# 5.0
# 80

# %%
len(Stars)
# Out:
# 80

# %%
dictionary={'Name':Name,'Price':Price,'Stars':Stars,'Reviews':Reviews,'Store':Store,'Country':Country}
df=pd.DataFrame.from_dict(dictionary)
df
# Out:
#                                                  Name Price Stars Reviews  \
# 0   Vivo_ Y20 / Y12s / Y12i Anti Shock Drop Resist...   420   5.0     17
# 1   Huawei Y9s Airbag Case Anti Shock and Anti-Scr...   129   4.8     38
# 2   Xiaomi Redmi Note 8 Shockproof Airbag Silicone...   129   4.9     28
# 3   Realmee GTMaster Case , Soft TPU Camera Protec...   216   4.8     44
# 4   Google Pixel 4 XL , Full Back Protection Sheet...    92   4.4     47
# ..                                                ...   ...   ...     ...
# 75  Xiaomi Redmi Note 8 Matte Soft Silicon Shockpr...   180   5.0      8
# 76  Xiaomi Redmi 6 AirBag anti shock Drop Resistan...   129   5.0      5
# 77  Samsung Galaxy S6 MATTE BLACK FLEXIBLE TPU CAS...   159   4.5     13
# 78  Nokia 2.2 Anti Shock Air Cushions Drop Resista...   190   4.7     12
# 79  Leweisi Carbon Fiber Bumper Phone Case For LG ...   569   5.0      5
#
#       Store   Country
# 0   Private  Pakistan
# 1   Private  Pakistan
# ...

# %%
dictionary={'Name':Name,'Price':Price,'Stars':Stars,'Reviews':Reviews,'Store':Store,'Country':Country}
df=pd.DataFrame.from_dict(dictionary)
df
# Out:
#                                                  Name Price Stars Reviews
# 0   For Vivo Y20 Y11S Y12A Y20SG Y3S Case Cartoon ...   564   4.8     66
# 1   for samsung s7 edge back Leather Case for sams...   650     0      0
# 2   Samsung A02S Antishock & Drop Resistance Armor...   420   4.8     17
# 3   Xiaomi Redmi Note 8 Shockproof Airbag Silicone...   129   4.9     28
# 4   Heavy Duty Respirator Mask Anti Pollution Filt...   395   4.8     31
# ..                                                ...   ...   ...     ...
# 75  Samsung galaxy A21s Transparent 6D Crystal sil...   146   4.9     11
# 76  For OnePlus 7T - Premium Liquid Silicone Silky...   449   4.8     31
# 77  Lenuo Phone Case for Samsung Galaxy A7 2018 Si...   669   4.9     47
# 78  Samsung Galaxy M31 Anti-Shock Air Cushions Dro...   129   4.8     16
# 79  Samsung Galaxy A51 Airbag Case Anti Shock and ...   179   4.8     50
#
# [80 rows x 4 columns]

# %%
#Output
df
# Out:
#                                                  Name  Price  Stars  Reviews
# 0   Lenuo Luxury 6D Plating Soft Casing Silicone S...    837    4.6       14
# 1   Lenuo Luxury 6D Plating Soft Casing Silicone S...    837    4.7       23
# 2   Xiaomi Redmi Note 4 Case , Smoky Matte Shock P...    249    4.9       33
# 3   Huawei Nova Plus MATTE BLACK FLEXIBLE TPU CASE...    149    5.0        5
# 4   For Sony Xperia XZ3 Heavy Duty Armor Tough Hyb...    649    5.0       25
# ..                                                ...    ...    ...      ...
# 75  Xiaomi Redmi Note 7 / Note 7Pro Case , Smoky M...    249    4.7       46
# 76  Xiaomi Poco F3 Case , Soft TPU Camera Protecti...    185    4.9       35
# 77  Infinix Note 10 Pro , Full Protection Vinyl Sk...     99    4.6      112
# 78  Huawei Nova 3i Antishock Drop Resistance Armor...    449    5.0       58
# 79  Handfree Cover Charger Hard Case eva Coin Carr...    127    4.7       75
#
# [80 rows x 4 columns]

# %% [markdown]
# # Question 3  (30 marks)

# %% [markdown]
# <!-- Which Products are on Flash sale? Display Product name, Actual Price, Discounted Price, Discount Percentage, Rating, No. of Reviews, Top 3 reviews displayed.
#
# Display output must be like this. Products may vary. -->
#
# If a user wants to make a store to sell something, lets say "Mobile Covers". He/She wants to see folowing things:
# 1. Top 10 Sellers store names
# 2. Daraz Mall Store/ Private store
# 3. Total "Mobile Covers" listings on his store
# 4. Avg Prices
# 5. Avg Units selling
# 6. Positive Seller Ratings
# 7. Seller Country

# %%
#Run this cell to see the sample output
import pandas as pd
pd.read_csv('output.csv')
# Out:
#                                     Store Name Daraz Mall/Private  Avg Price  \
# 0                                     Hontinga         Daraz Mall        565
# 1  ABC MOBILE ACCESSORIES STORE ( FAISALABAD )            Private         95
#
#    Listings  Avg unit selling  Seller Ratings   Country  Followers
# 0    187414               110              93  Overseas      29919
# 1       438                29              93  Pakistan      11969

# %%
import time
import pandas as pd
from selenium import webdriver
from selenium.webdriver.edge.options import Options
from selenium.webdriver.common.keys import Keys
# from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By
from selenium.common.exceptions import NoSuchElementException

# %%
url = 'https://www.daraz.pk/mobile-cases-covers/?page=1'
path='/Downloads/chromedriver_win32'
options = Options()
driver=webdriver.Chrome('chromedriver')
driver.get(url)
storeName=[]
storeType=[]
avgPrice=[]
listing=[]
sellerRating=[]
country=[]
followers=[]
flag=True
count=0
while flag:
    for i in range(1,41):
        fastScroll(driver)
        time.sleep(1)
        try:

            button=driver.find_element(By.XPATH,'//div[@class="box--ujueT"]/div[@class="gridItem--Yd0sa"][{}]'.format(i))
            button.click()
        except:
            try:
                driver.refresh()
                time.sleep(1)
                fastScroll(driver)
                driver.find_element(By.XPATH,'//div[@class="box--ujueT"]/div[@class="gridItem--Yd0sa"][{}]'.format(i)).click()
            except:
                x=1
        Q3Scroll(driver)
        try:
            driver.find_element(By.XPATH,"//span[@class='sfo__close']").click()
        except:
            x=1
        try:
            name =driver.find_element(By.XPATH,'//div[@class="seller-name__detail"]/a').text
            nextPage=driver.find_element(By.XPATH,'//div[@class="seller-name__detail"]/a')
            price=driver.find_element(By.XPATH,"//div[@class='pdp-product-price']/span").text
            price=price[4:]
            price=int(price)
            con=checkcountry(driver)
            store=checkStore(driver)
            rating=driver.find_element(By.XPATH,'//div[@class="info-content"][1]/div[2]').text
            if name not in storeName:
                nextPage.click()
                time.sleep(1)
                follow=driver.find_element(By.XPATH,'//div[@class="pi-layout-container"]/div/div/div/div/div/div/div/div/div/div/div').text
                follow=follow[:-10]
                storeName.append(name)
                storeType.append(store)
                avgPrice.append(price)
                sellerRating.append(rating)
                followers.append(int(follow))
                country.append(con)
                listing.append(1)
                driver.back()
            else:
                index=storeName.index(name)

                listing[index]=listing[index]+1
                avgPrice[index]=avgPrice[index]+price
            driver.back()
        except:
            try:
                driver.refresh()
                time.sleep(1)
                fastScroll(driver)
                name =driver.find_element(By.XPATH,'//div[@class="seller-name__detail"]/a').text
                nextPage=driver.find_element(By.XPATH,'//div[@class="seller-name__detail"]/a')
                price=driver.find_element(By.XPATH,"//div[@class='pdp-product-price']/span").text
                price=price[4:]
                price=int(price)
                con=checkcountry(driver)
                store=checkStore(driver)
                rating=driver.find_element(By.XPATH,'//div[@class="info-content"][1]/div[2]').text
                if name not in storeName:
                    nextPage.click()
                    time.sleep(1)
                    follow=driver.find_element(By.XPATH,'//div[@class="pi-layout-container"]/div/div/div/div/div/div/div/div/div/div/div').text
                    follow=follow[:-10]
                    storeName.append(name)
                    storeType.append(store)
                    avgPrice.append(price)
                    sellerRating.append(rating)
                    followers.append(int(follow))
                    country.append(con)
                    listing.append(1)
                    driver.back()
                else:
                    index=storeName.index(name)

                    listing[index]=listing[index]+1
                    avgPrice[index]=avgPrice[index]+price
                driver.back()
            except:
                x=2
    try:
        nextPage= driver.find_element(By.XPATH,"//li[@title='Next Page']")
        nextPage.click()
    except:
        try:
            driver.refresh()
            scroll(driver)
            nextPage= driver.find_element(By.XPATH,"//li[@title='Next Page']")
            nextPage.click()
        except:
            flag=False

for i,j in enumerate(listing):
    avgPrice[i]=avgPrice[i]/j
print (storeName)
# Out:
# ['Multi Mobile Wholeseller (Lahore)', 'Accessriologist', 'ABC MOBILE ACCESSORIES STORE ( FAISALABAD )', 'Multi Mobiles', 'Chase Store', 'GADGETERZ', 'TA Rock Traders (Lahore)', 'Cell net Pro', 'Multi Mobile (Lahore)', 'Aadii Store', 'Future Accessories', 'Quick-To Buy', 'Electronic Hub 1588358204', 'KD Accessories (Karachi)', 'Ali Gadgets (Islamabad)', 'Deal Box', 'I Care Shop', 'Accessories Den', 'Powerlinks', 'icasecover', 'Pcheex', 'UCUC', 'Tariq mehmood Shop', 'E-Case', 'Phone Tech', 'Leweisi', 'Jaybee Collection', 'WDM Mart', 'ZH stationery', 'Jizetin Official Store', 'THE COSMOS', 'Biruiqu', 'Business Bustle', 'Hontinga', 'FlashPoint', 'shipper', 'lthmy', '786Case', 'DECORATORS', '98 Case', 'Click Toy Buy', 'COROGI', 'Secure Homes (Karachi)', 'Lavish Traders (Lahore)', 'Aa store 1590333532', 'Pluscase', 'BZL Accessories', 'MISC (Lahore)', 'Protector of Phone', 'Youksh', 'TZ Collections', 'M n M', 'GATEWAY (Lahore)', 'Lereach', 'Areeba Collections 1611304090', '300 Stores', 'car
# ...

# %%
data={"Store Name":storeName,"Daraz-Mall/Private":storeType,"Avg Price":avgPrice,"Listings":listing,"SellerRating":sellerRating,"Country":country,"Followers":followers}
df=pd.DataFrame.from_dict(data)
df.nlargest(10,'Followers')
# Out:
#                                      Store Name Daraz-Mall/Private  \
# 73                        Y.M Traders (Karachi)            Private
# 33                                     Hontinga         Daraz Mall
# 79                          Buy & Buy (Karachi)            Private
# 59                                      Vantime         Daraz Mall
# 61                                        Lenuo         Daraz Mall
# 15                                     Deal Box            Private
# 2   ABC MOBILE ACCESSORIES STORE ( FAISALABAD )            Private
# 8                         Multi Mobile (Lahore)            Private
# 21                                         UCUC         Daraz Mall
# 41                                       COROGI            Private
#
#      Avg Price  Listings SellerRating   Country  Followers
# 73  114.000000         1          86%  Pakistan      46989
# 33  489.875000         8          93%  Overseas      30801
# ...
